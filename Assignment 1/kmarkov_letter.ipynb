# %% [markdown]
# #K-Markov Sampling for Letters dataset

# %%
# Import all dependencies
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import scale

# %%
# mount drive for easy import and export of data
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# initialise dataframe with letter dataset
letters = pd.read_csv("letter-recognition.csv")
letters.columns = ['letter', 'xbox', 'ybox', 'width', 'height', 'onpix', 'xbar','ybar', 'x2bar', 'y2bar', 'xybar', 'x2ybar', 'xy2bar', 'xedge','xedgey', 'yedge', 'yedgex']

# %% [markdown]
# Step-I

# %%
# initialise parameters
markov= pd.DataFrame(columns = letters.columns)
uniqChar=list(np.sort(letters['letter'].unique()))
classCNT=len(uniqChar)
limit=100
m=classCNT*limit
charNo={}
c=0
for i in uniqChar:
    charNo[i]=c
    c+=1
mAZ={i:0 for i in uniqChar}

# %%
# Chose parameters for markov sampling
k=5
q=1.2
acc=0

# %%
# Train a linear Model on N[here 2000] size train set
X = letters.drop("letter", axis = 1)
y = letters['letter']

X_scaled = scale(X)

# train test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.9, random_state = 101)
model_linear = SVC(kernel='linear')
model_linear.fit(X_train, y_train)

# predict
y_pred = model_linear.predict(X_test)

# %%
y_pred
# Out:
# array(['P', 'E', 'M', ..., 'Q', 'F', 'X'], dtype=object)

# %% [markdown]
# Step-II

# %%
# Chosing a random sample as first of markov chain
i=np.random.randint(letters.shape[0])
z0=letters.iloc[i]
y0=model_linear.predict(np.array([z0.drop('letter')]))[0]
if m%classCNT==0:
    mAZ[z0['letter']]+=1

# %%
d={}
for i,val in z0.items():
    print(i,val)
    d[i]=val
markov.append(d,ignore_index=True)
markov
# Out:
# letter K
# xbox 8
# ybox 13
# width 8
# height 7
# onpix 4
# xbar 9
# ybar 7
# x2bar 3
# y2bar 9
# xybar 7
# x2ybar 3
# xy2bar 6
# xedge 5
# xedgey 4
# yedge 8
# yedgex 8
# Empty DataFrame
# Columns: [letter, xbox, ybox, width, height, onpix, xbar, ybar, x2bar, y2bar, xybar, x2ybar, xy2bar, xedge, xedgey, yedge, yedgex]
# Index: []

# %%
predProb=[]

# %%
# Utility Function for loop condition
def exist(dic,limit):
    for i,val in dic.items():
        if val<limit:
            return True
    return False

# %%
# Utility loss Function
def lossF(actual,pred):
    if actual==pred:
        return 1.0
    return np.exp(-2)

# %%
# Utility Function for getting class index
def getNo(ch):
    return charNo[ch]

# %%
# Utility function for training subsequent models
def train(data):
    
    X = data.drop("letter", axis = 1)
    y = data['letter']

    # train test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.8, random_state = 101)
    model_linear = SVC(kernel='linear')
    model_linear.fit(X_train, y_train)

    return model_linear

# %%
lst=[]

# %% [markdown]
# Step-III TO Step-VII

# %%
# Loop markov chain generator k times
for km in range(2):
    # Reset parameters for next markov chain
    if km!=0:
        predProb=[]
        model_linear=train(markov)
        markov= pd.DataFrame(columns = letters.columns)
        mAZ={i:0 for i in uniqChar}
    lst=[]
    
    # Chosing a random sample as first of markov chain
    i=np.random.randint(letters.shape[0])
    z0=letters.iloc[i]
    y0=model_linear.predict(np.array([z0.drop('letter')]))[0]
    if m%classCNT==0:
        mAZ[z0['letter']]+=1
    print("Entering...")
    while exist(mAZ,limit):
        # choosing a random sample
        i=np.random.randint(letters.shape[0])
        while i in lst:
            i=np.random.randint(letters.shape[0])
        z1=letters.iloc[i]
        y1=model_linear.predict(np.array([z1.drop('letter')]))[0]
        n=lossF(z1['letter'],y1)
        d=lossF(z0['letter'],y0)
        p=n/d
        
        # Deciding of acceptance of chosen sample and its probability in markov chain
        if acc==k:
            acc=0
            p2=q*p
            p2=min(p2,1)
            predProb.append([z1['letter'],y1,p2])
            markov=markov.append(z1)
            z0=z1
            mAZ[z1['letter']]+=1
            acc+=1
            lst.append(i)
        elif p==1 and z0['letter']==z1['letter']:
            n=np.exp(-getNo(y1)*getNo(z1['letter']))
            d=np.exp(-getNo(y0)*getNo(z0['letter']))

            p1=n/d
            p1=min(p1,1)
            predProb.append([z1['letter'],y1,p1])
            markov=markov.append(z1)
            z0=z1
            mAZ[z1['letter']]+=1
            acc+=1
            lst.append(i)
        elif p<1:
            predProb.append([z1['letter'],y1,p])
            markov=markov.append(z1)
            z0=z1
            mAZ[z1['letter']]+=1
            acc+=1
            lst.append(i)
        elif p==1 and z0['letter']!=z1['letter']:
            predProb.append([z1['letter'],y1,p])
            markov=markov.append(z1)
            z0=z1
            mAZ[z1['letter']]+=1
            acc+=1
            lst.append(i)
# Out:
# Entering...
# Entering...

# %%
markov
# Out:
#       letter xbox ybox width height  ... xy2bar xedge xedgey yedge yedgex
# 17428      O    6   10     7      7  ...      9     4      5     8      5
# 8681       Z    4    6     5      4  ...      6     2      6     9      5
# 1092       K    8   15     8      8  ...     11     5      4    11      7
# 16779      R    3   10     4      7  ...      8     3      5     8     10
# 1947       E    4    7     6      5  ...      8     3      4     8      6
# ...      ...  ...  ...   ...    ...  ...    ...   ...    ...   ...    ...
# 14120      K    5   11     7      8  ...      8     7      7     7      7
# 8158       S    7   10     8      7  ...      8     2      5     5     10
# 3836       X    4    4     6      3  ...      9     3      3     7      6
# 18434      A    3    4     5      3  ...      9     2      2     6      8
# 12926      V    4    7     6      6  ...      8     6      7     9      8
#
# [4431 rows x 17 columns]

# %%
predProb
# Out:
# [['O', 'D', 1.0],
#  ['Z', 'S', 1.0],
#  ['K', 'C', 1.0],
#  ['R', 'H', 1.0],
#  ['E', 'E', 1],
#  ['B', 'I', 1.0],
#  ['B', 'B', 1.0],
#  ['W', 'W', 1.0],
#  ['B', 'R', 1.0],
#  ['O', 'O', 1],
#  ['O', 'Q', 6.282880511239462e-92],
#  ['K', 'A', 1.0],
#  ['M', 'U', 1.0],
#  ['N', 'D', 1.0],
#  ['W', 'W', 1],
#  ['Q', 'O', 1.0],
#  ['P', 'F', 1.0],
#  ['X', 'R', 1.0],
#  ['L', 'Q', 1.0],
#  ['S', 'X', 1],
#  ['X', 'B', 1.0],
#  ['O', 'H', 1.0],
#  ['S', 'Z', 1.0],
#  ['J', 'I', 1.0],
#  ['R', 'R', 1],
#  ['H', 'K', 1.0],
#  ['B', 'V', 1.0],
#  ['A', 'A', 1.0],
#  ['P', 'F', 1.0],
#  ['W', 'W', 1],
#  ['Q', 'O', 1.0],
#  ['J', 'F', 1.0],
#  ['F', 'P', 1.0],
#  ['D', 'N', 1.0],
#  ['W', 'W', 1],
#  ['H', 'R', 1.0],
#  ['R', 'N', 1.0],
#  ['O', 'P', 1.0],
#  ['S', 'I', 1.0],
#  ['W', 'W', 1],
#  ['F', 'I', 1.0],
#  ['U', 'N', 1.0],
#  ['H', 'J', 1.0],
#  ['Y', 'V', 1.0],
#  ['O', 'O', 1],
#  ['Q', 'E', 1.0],
#  ['S', 'J', 1.0],
#  ['P', 'G', 1.0],
#  ['K', 'R', 1.0],
#  ['J', 'J', 1],
#  ['I', 'D', 1.0],
#  ['L', 'I', 1.0],
#  ['M', 'U', 1.0],
#  ['Y', 'V', 1.0],
#  ['C', 'C', 1],
#  ['X', 'K', 1.0],
#  ['Y', 'T', 1.0],
#  ['K', 'M', 1.0],
#  ['T', 'G', 1.0],
#  ['V', 'V', 1],
#  ['Y', 'V', 1.0],
#  ['N', 'M', 1.0],
#  ['I', 'S', 1.0],
#  ['H', 'V', 1.0],
#  ['N', 'N', 1],
#  ['S', 'B', 1.0],
#  ['U', 'T', 1.0],
#  ['L', 'Q', 1.0],
#  ['D', 'B', 1.0],
#  ['T', 'T', 1],
#  ['Q', 'G', 1.0],
#  ['I', 'X', 1.0],
#  ['Y', 'V', 1.0],
#  ['Z', 'S', 1.0],
#  ['B', 'B', 1],
#  ['L', 'L', 1.0],
#  ['S', 'Z', 1.0],
#  ['K', 'Q', 1.0],
#  ['S', 'Z', 1.0],
#  ['J', 'J', 1],
#  ['F', 'S', 1.0],
#  ['K', 'D', 1.0],
#  ['V', 'T', 1.0],
#  ['O', 'P', 1.0],
#  ['Y', 'T', 1],
#  ['K', 'C', 1.0],
#  ['P', 'F', 1.0],
#  ['Z', 'S', 1.0],
#  ['R', 'A', 1.0],
#  ['S', 'E', 1],
#  ['V', 'U', 1.0],
#  ['W', 'M', 1.0],
#  ['U', 'N', 1.0],
#  ['C', 'E', 1.0],
#  ['Y', 'Y', 1],
#  ['H', 'N', 1.0],
#  ['Q', 'D', 1.0],
#  ['S', 'I', 1.0],
#  ['I', 'D', 1.0],
#  ['Q', 'Q', 1],
#  ['S', 'B', 1.0],
#  ['H', 'F', 1.0],
#  ['C', 'G', 1.0],
#  ['B', 'O', 1.0],
#  ['J', 'J', 1],
#  ['A', 'Q', 1.0],
#  ['G', 'O', 1.0],
#  ['Y', 'V', 1.0],
#  ['M', 'R', 1.0],
#  ['D', 'D', 1],
#  ['S', 'Q', 1.0],
#  ['K', 'R', 1.0],
#  ['Z', 'S', 1.0],
#  ['P', 'G', 1.0],
#  ['T', 'T', 1],
#  ['Q', 'G', 1.0],
#  ['W', 'M', 1.0],
#  ['P', 'D', 1.0],
#  ['K', 'E', 1.0],
#  ['P', 'D', 1],
#  ['Q', 'G', 1.0],
#  ['X', 'J', 1.0],
#  ['G', 'R', 1.0],
#  ['R', 'H', 1.0],
#  ['E', 'E', 1],
#  ['J', 'I', 1.0],
#  ['T', 'S', 1.0],
#  ['Z', 'S', 1.0],
#  ['W', 'M', 1.0],
#  ['C', 'C', 1],
#  ['O', 'G', 1.0],
#  ['Q', 'G', 1.0],
#  ['G', 'Q', 1.0],
#  ['U', 'O', 1.0],
#  ['M', 'M', 1],
#  ['H', 'R', 1.0],
#  ['G', 'A', 1.0],
#  ['C', 'U', 1.0],
#  ['H', 'K', 1.0],
#  ['G', 'G', 1],
#  ['C', 'U', 1.0],
#  ['S', 'B', 1.0],
#  ['D', 'B', 1.0],
#  ['H', 'F', 1.0],
#  ['S', 'Z', 1],
#  ['A', 'Y', 1.0],
#  ['H', 'K', 1.0],
#  ['S', 'E', 1.0],
#  ['X', 'I', 1.0],
#  ['V', 'V', 1],
#  ['C', 'G', 1.0],
#  ['O', 'W', 1.0],
#  ['M', 'N', 1.0],
#  ['C', 'K', 1.0],
#  ['A', 'A', 1],
#  ['H', 'D', 1.0],
#  ['P', 'G', 1.0],
#  ['B', 'R', 1.0],
#  ['U', 'U', 1.0],
#  ['O', 'M', 1],
#  ['Q', 'O', 1.0],
#  ['C', 'E', 1.0],
#  ['G', 'Q', 1.0],
#  ['G', 'Q', 8.194012623990515e-40],
#  ['L', 'L', 1],
#  ['K', 'E', 1.0],
#  ['Z', 'S', 1.0],
#  ['P', 'F', 1.0],
#  ['N', 'D', 1.0],
#  ['R', 'R', 1],
#  ['Y', 'T', 1.0],
#  ['E', 'S', 1.0],
#  ['H', 'K', 1.0],
#  ['I', 'F', 1.0],
#  ['T', 'T', 1],
#  ['F', 'E', 1.0],
#  ['I', 'X', 1.0],
#  ['W', 'N', 1.0],
#  ['G', 'S', 1.0],
#  ['M', 'M', 1],
#  ['K', 'X', 1.0],
#  ['G', 'L', 1.0],
#  ['S', 'Z', 1.0],
#  ['E', 'S', 1.0],
#  ['O', 'O', 1],
#  ['P', 'F', 1.0],
#  ['C', 'E', 1.0],
#  ['X', 'G', 1.0],
#  ['Q', 'O', 1.0],
#  ['D', 'S', 1],
#  ['S', 'Z', 1.0],
#  ['T', 'H', 1.0],
#  ['M', 'N', 1.0],
#  ['D', 'X', 1.0],
#  ['Y', 'T', 1],
#  ['A', 'J', 1.0],
#  ['G', 'E', 1.0],
#  ['J', 'I', 1.0],
#  ['U', 'N', 1.0],
#  ['U', 'U', 1],
#  ['O', 'H', 1.0],
#  ['O', 'G', 3.975449735908647e-31],
#  ['G', 'Q', 1.0],
#  ['J', 'I', 1.0],
#  ['P', 'P', 1],
#  ['G', 'F', 1.0],
#  ['F', 'D', 1.0],
#  ['W', 'V', 1.0],
#  ['C', 'G', 1.0],
#  ['T', 'T', 1],
#  ['F', 'E', 1.0],
#  ['O', 'D', 1.0],
#  ['K', 'M', 1.0],
#  ['L', 'E', 1.0],
#  ['Z', 'S', 1],
#  ['P', 'D', 1.0],
#  ['T', 'S', 1.0],
#  ['H', 'D', 1.0],
#  ['C', 'U', 1.0],
#  ['D', 'D', 1],
#  ['R', 'B', 1.0],
#  ['F', 'I', 1.0],
#  ['H', 'D', 1.0],
#  ['Q', 'O', 1.0],
#  ['Q', 'Q', 1],
#  ['U', 'Y', 1.0],
#  ['O', 'H', 1.0],
#  ['H', 'O', 1.0],
#  ['H', 'K', 4.359610000063081e-28],
#  ['V', 'V', 1],
#  ['L', 'Q', 1.0],
#  ['Y', 'X', 1.0],
#  ['Z', 'S', 1.0],
#  ['C', 'O', 1.0],
#  ['I', 'I', 1],
#  ['O', 'N', 1.0],
#  ['S', 'I', 1.0],
#  ['U', 'N', 1.0],
#  ['Z', 'F', 1.0],
#  ['Q', 'Q', 1],
#  ['Z', 'E', 1.0],
#  ['S', 'Z', 1.0],
#  ['T', 'S', 1.0],
#  ['P', 'D', 1.0],
#  ['I', 'I', 1],
#  ['T', 'H', 1.0],
#  ['I', 'B', 1.0],
#  ['N', 'M', 1.0],
#  ['F', 'P', 1.0],
#  ['D', 'D', 1],
#  ['F', 'N', 1.0],
#  ['G', 'R', 1.0],
#  ['Y', 'V', 1.0],
#  ['N', 'U', 1.0],
#  ['I', 'I', 1],
#  ['L', 'G', 1.0],
#  ['F', 'P', 1.0],
#  ['G', 'S', 1.0],
#  ['G', 'K', 3.532628572200807e-24],
#  ['B', 'B', 1],
#  ['I', 'I', 1.0],
#  ['G', 'Q', 1.0],
#  ['G', 'C', 0.0024787521766663585],
#  ['F', 'T', 1.0],
#  ['K', 'K', 1],
#  ['E', 'R', 1.0],
#  ['Z', 'E', 1.0],
#  ['J', 'F', 1.0],
#  ['X', 'S', 1.0],
#  ['E', 'E', 1],
#  ['S', 'Z', 1.0],
#  ['Q', 'O', 1.0],
#  ['E', 'G', 1.0],
#  ['D', 'N', 1.0],
#  ['B', 'B', 1],
#  ['O', 'O', 1.0],
#  ['X', 'G', 1.0],
#  ['O', 'H', 1.0],
#  ['G', 'Q', 1.0],
#  ['F', 'F', 1],
#  ['S', 'Z', 1.0],
#  ['Q', 'J', 1.0],
#  ['G', 'L', 1.0],
#  ['H', 'O', 1.0],
#  ['U', 'U', 1],
#  ['G', 'E', 1.0],
#  ['A', 'R', 1.0],
#  ['S', 'E', 1.0],
#  ['S', 'Q', 5.501611081740457e-118],
#  ['H', 'H', 1],
#  ['I', 'J', 1.0],
#  ['R', 'B', 1.0],
#  ['T', 'X', 1.0],
#  ['Y', 'V', 1.0],
#  ['X', 'X', 1],
#  ['U', 'O', 1.0],
#  ['B', 'R', 1.0],
#  ['Q', 'Q', 1.0],
#  ['N', 'M', 1.0],
#  ['S', 'S', 1],
#  ['G', 'Q', 1.0],
#  ['U', 'A', 1.0],
#  ['T', 'S', 1.0],
#  ['G', 'C', 1.0],
#  ['Y', 'S', 1],
#  ['O', 'H', 1.0],
#  ['G', 'S', 1.0],
#  ['G', 'E', 1.522997974471263e-08],
#  ['I', 'J', 1.0],
#  ['H', 'O', 1],
#  ['W', 'M', 1.0],
#  ['S', 'I', 1.0],
#  ['C', 'E', 1.0],
#  ['H', 'Q', 1.0],
#  ['D', 'D', 1],
#  ['J', 'I', 1.0],
#  ['S', 'I', 1.0],
#  ['Y', 'V', 1.0],
#  ['E', 'C', 1.0],
#  ['G', 'G', 1],
#  ['I', 'S', 1.0],
#  ['N', 'V', 1.0],
#  ['Q', 'B', 1.0],
#  ['G', 'Q', 1.0],
#  ['V', 'V', 1],
#  ['R', 'K', 1.0],
#  ['S', 'Z', 1.0],
#  ['O', 'W', 1.0],
#  ['G', 'H', 1.0],
#  ['O', 'O', 1],
#  ['C', 'G', 1.0],
#  ['S', 'F', 1.0],
#  ['S', 'L', 6.714184288211592e-79],
#  ['Z', 'E', 1.0],
#  ['L', 'K', 1],
#  ['J', 'Z', 1.0],
#  ['Z', 'A', 1.0],
#  ['J', 'I', 1.0],
#  ['X', 'T', 1.0],
#  ['K', 'E', 1],
#  ['H', 'B', 1.0],
#  ['Q', 'B', 1.0],
#  ['E', 'C', 1.0],
#  ['D', 'X', 1.0],
#  ['L', 'L', 1],
#  ['U', 'N', 1.0],
#  ['J', 'I', 1.0],
#  ['S', 'E', 1.0],
#  ['E', 'S', 1.0],
#  ['F', 'F', 1],
#  ['Z', 'S', 1.0],
#  ['O', 'P', 1.0],
#  ['D', 'O', 1.0],
#  ['J', 'N', 1.0],
#  ['I', 'I', 1],
#  ['R', 'D', 1.0],
#  ['J', 'Z', 1.0],
#  ['E', 'S', 1.0],
#  ['R', 'B', 1.0],
#  ['F', 'F', 1],
#  ['D', 'B', 1.0],
#  ['C', 'L', 1.0],
#  ['P', 'O', 1.0],
#  ['A', 'U', 1.0],
#  ['T', 'T', 1],
#  ['K', 'X', 1.0],
#  ['S', 'R', 1.0],
#  ['X', 'L', 1.0],
#  ['R', 'B', 1.0],
#  ['E', 'E', 1],
#  ['I', 'A', 1.0],
#  ['K', 'R', 1.0],
#  ['W', 'V', 1.0],
#  ['F', 'C', 1.0],
#  ['M', 'M', 1],
#  ['H', 'O', 1.0],
#  ['W', 'M', 1.0],
#  ['Y', 'F', 1.0],
#  ['Q', 'O', 1.0],
#  ['L', 'L', 1],
#  ['G', 'Q', 1.0],
#  ['Q', 'O', 1.0],
#  ['Y', 'A', 1.0],
#  ['F', 'U', 1.0],
#  ['Q', 'O', 1],
#  ['I', 'J', 1.0],
#  ['G', 'Q', 1.0],
#  ['Z', 'J', 1.0],
#  ['A', 'J', 1.0],
#  ['P', 'B', 1],
#  ['S', 'Z', 1.0],
#  ['F', 'V', 1.0],
#  ['Y', 'T', 1.0],
#  ['S', 'B', 1.0],
#  ['I', 'I', 1],
#  ['A', 'U', 1.0],
#  ['X', 'E', 1.0],
#  ['O', 'W', 1.0],
#  ['K', 'E', 1.0],
#  ['D', 'D', 1],
#  ['Q', 'G', 1.0],
#  ['T', 'F', 1.0],
#  ['I', 'F', 1.0],
#  ['R', 'B', 1.0],
#  ['O', 'O', 1],
#  ['H', 'B', 1.0],
#  ['J', 'I', 1.0],
#  ['C', 'G', 1.0],
#  ['H', 'T', 1.0],
#  ['F', 'G', 1],
#  ['G', 'Q', 1.0],
#  ['B', 'V', 1.0],
#  ['S', 'Q', 0.1353352832366127],
#  ['D', 'O', 1.0],
#  ['M', 'M', 1],
#  ['J', 'I', 1.0],
#  ['W', 'U', 1.0],
#  ['Q', 'G', 1.0],
#  ['Y', 'E', 1.0],
#  ['V', 'V', 1],
#  ['L', 'E', 1.0],
#  ['E', 'B', 1.0],
#  ['C', 'G', 1.0],
#  ['S', 'B', 1.0],
#  ['D', 'D', 1],
#  ['L', 'E', 1.0],
#  ['B', 'R', 1.0],
#  ['T', 'T', 1.0],
#  ['Z', 'E', 1.0],
#  ['E', 'E', 1],
#  ['B', 'V', 1.0],
#  ['I', 'I', 1.0],
#  ['G', 'Q', 1.0],
#  ['F', 'T', 1.0],
#  ['M', 'M', 1],
#  ['Z', 'J', 1.0],
#  ['Q', 'E', 1.0],
#  ['Z', 'J', 1.0],
#  ['E', 'L', 1.0],
#  ['F', 'F', 1],
#  ['X', 'I', 1.0],
#  ['F', 'N', 1.0],
#  ['F', 'C', 0.006737946999085468],
#  ['U', 'H', 1.0],
#  ['D', 'D', 1],
#  ['F', 'E', 1.0],
#  ['Z', 'S', 1.0],
#  ['Y', 'F', 1.0],
#  ['H', 'D', 1.0],
#  ['F', 'F', 1],
#  ['S', 'B', 1.0],
#  ['O', 'G', 1.0],
#  ['Y', 'V', 1.0],
#  ['L', 'E', 1.0],
#  ['T', 'T', 1],
#  ['F', 'Y', 1.0],
#  ['E', 'Q', 1.0],
#  ['Z', 'E', 1.0],
#  ['W', 'U', 1.0],
#  ['K', 'E', 1],
#  ['B', 'H', 1.0],
#  ['T', 'T', 1.0],
#  ['I', 'F', 1.0],
#  ['D', 'O', 1.0],
#  ['Q', 'Q', 1],
#  ['G', 'Q', 1.0],
#  ['L', 'Q', 1.0],
#  ['Y', 'V', 1.0],
#  ['H', 'F', 1.0],
#  ['Y', 'Y', 1],
#  ['Z', 'J', 1.0],
#  ['H', 'N', 1.0],
#  ['H', 'D', 8.315287191035679e-07],
#  ['F', 'E', 1.0],
#  ['X', 'X', 1],
#  ['P', 'D', 1.0],
#  ['G', 'E', 1.0],
#  ['W', 'M', 1.0],
#  ['R', 'A', 1.0],
#  ['N', 'N', 1],
#  ['R', 'H', 1.0],
#  ['N', 'M', 1.0],
#  ['P', 'G', 1.0],
#  ['X', 'K', 1.0],
#  ['D', 'D', 1],
#  ['G', 'C', 1.0],
#  ['X', 'K', 1.0],
#  ['W', 'M', 1.0],
#  ['F', 'Y', 1.0],
#  ['K', 'K', 1],
#  ['K', 'G', 1.9287498479639176e-22],
#  ['Z', 'S', 1.0],
#  ['M', 'W', 1.0],
#  ['Y', 'T', 1.0],
#  ['V', 'V', 1],
#  ['L', 'H', 1.0],
#  ['R', 'N', 1.0],
#  ['C', 'E', 1.0],
#  ['K', 'E', 1.0],
#  ['M', 'M', 1],
#  ['Q', 'B', 1.0],
#  ['L', 'D', 1.0],
#  ['P', 'F', 1.0],
#  ['F', 'I', 1.0],
#  ['V', 'V', 1],
#  ['L', 'E', 1.0],
#  ['S', 'E', 1.0],
#  ['Y', 'F', 1.0],
#  ['R', 'K', 1.0],
#  ['P', 'N', 1],
#  ['H', 'K', 1.0],
#  ['F', 'P', 1.0],
#  ['S', 'B', 1.0],
#  ['Y', 'V', 1.0],
#  ['Y', 'Y', 1],
#  ['I', 'F', 1.0],
#  ['C', 'L', 1.0],
#  ['U', 'V', 1.0],
#  ['Q', 'G', 1.0],
#  ['C', 'G', 1],
#  ['V', 'R', 1.0],
#  ['I', 'D', 1.0],
#  ['N', 'H', 1.0],
#  ['E', 'S', 1.0],
#  ['L', 'L', 1],
#  ['S', 'E', 1.0],
#  ['L', 'Z', 1.0],
#  ['Z', 'S', 1.0],
#  ['F', 'T', 1.0],
#  ['B', 'B', 1],
#  ['N', 'N', 1.0],
#  ['U', 'H', 1.0],
#  ['Q', 'B', 1.0],
#  ['R', 'M', 1.0],
#  ['D', 'D', 1],
#  ['R', 'O', 1.0],
#  ['Z', 'S', 1.0],
#  ['P', 'F', 1.0],
#  ['B', 'H', 1.0],
#  ['N', 'M', 0.16240233988393524],
#  ['Y', 'V', 1.0],
#  ['Z', 'J', 1.0],
#  ['F', 'Y', 1.0],
#  ['V', 'W', 1.0],
#  ['K', 'K', 1],
#  ['R', 'D', 1.0],
#  ['A', 'U', 1.0],
#  ['O', 'W', 1.0],
#  ['O', 'W', 2.0769322043867094e-128],
#  ['T', 'T', 1],
#  ['X', 'I', 1.0],
#  ['S', 'B', 1.0],
#  ['R', 'K', 1.0],
#  ['X', 'F', 1.0],
#  ['H', 'D', 1],
#  ['X', 'G', 1.0],
#  ['G', 'Q', 1.0],
#  ['C', 'S', 1.0],
#  ['F', 'H', 1.0],
#  ['O', 'O', 1],
#  ['D', 'K', 1.0],
#  ['F', 'Y', 1.0],
#  ['R', 'B', 1.0],
#  ['I', 'D', 1.0],
#  ['V', 'T', 1],
#  ['Q', 'G', 1.0],
#  ['M', 'N', 1.0],
#  ['C', 'K', 1.0],
#  ['X', 'I', 1.0],
#  ['F', 'C', 1],
#  ['I', 'S', 1.0],
#  ['Y', 'V', 1.0],
#  ['G', 'Q', 1.0],
#  ['T', 'S', 1.0],
#  ['H', 'H', 1],
#  ['I', 'S', 1.0],
#  ['J', 'F', 1.0],
#  ['X', 'I', 1.0],
#  ['G', 'C', 1.0],
#  ['D', 'D', 1],
#  ['X', 'I', 1.0],
#  ['H', 'K', 1.0],
#  ['H', 'O', 3.014408785065374e-40],
#  ['O', 'D', 1.0],
#  ['T', 'T', 1],
#  ['G', 'C', 1.0],
#  ['H', 'D', 1.0],
#  ['H', 'K', 4.359610000063081e-28],
#  ['Z', 'E', 1.0],
#  ['A', 'A', 1],
#  ['G', 'M', 1.0],
#  ['S', 'B', 1.0],
#  ['Z', 'A', 1.0],
#  ['C', 'K', 1.0],
#  ['A', 'A', 1],
#  ['Z', 'S', 1.0],
#  ['Q', 'B', 1.0],
#  ['B', 'V', 1.0],
#  ['T', 'T', 1.0],
#  ['J', 'I', 1],
#  ['F', 'E', 1.0],
#  ['S', 'Z', 1.0],
#  ['H', 'T', 1.0],
#  ['R', 'M', 1.0],
#  ['Q', 'Q', 1],
#  ['C', 'U', 1.0],
#  ['S', 'Z', 1.0],
#  ['U', 'H', 1.0],
#  ['N', 'U', 1.0],
#  ['J', 'J', 1],
#  ['W', 'U', 1.0],
#  ['N', 'V', 1.0],
#  ['H', 'O', 1.0],
#  ['X', 'I', 1.0],
#  ['E', 'E', 1],
#  ['Z', 'S', 1.0],
#  ['Q', 'G', 1.0],
#  ['D', 'I', 1.0],
#  ['G', 'E', 1.0],
#  ['H', 'H', 1],
#  ['G', 'S', 1.0],
#  ['B', 'R', 1.0],
#  ['P', 'E', 0.1353352832366127],
#  ['E', 'L', 1.0],
#  ['E', 'E', 1],
#  ['C', 'K', 1.0],
#  ['S', 'Z', 1.0],
#  ['T', 'E', 1.0],
#  ['N', 'D', 1.0],
#  ['E', 'E', 1],
#  ['C', 'G', 1.0],
#  ['Y', 'F', 1.0],
#  ['H', 'X', 1.0],
#  ['K', 'R', 1.0],
#  ['V', 'V', 1],
#  ['D', 'R', 1.0],
#  ['J', 'N', 1.0],
#  ['C', 'G', 1.0],
#  ['F', 'T', 1.0],
#  ['L', 'L', 1],
#  ['N', 'H', 1.0],
#  ['E', 'X', 1.0],
#  ['F', 'E', 1.0],
#  ['D', 'P', 1.0],
#  ['X', 'X', 1],
#  ['L', 'I', 1.0],
#  ['Y', 'T', 1.0],
#  ['O', 'T', 1.0],
#  ['S', 'Z', 1.0],
#  ['B', 'B', 1],
#  ['Z', 'S', 0.1353352832366127],
#  ['Y', 'X', 1.0],
#  ['B', 'F', 1.0],
#  ['Q', 'Q', 1.0],
#  ['J', 'J', 1],
#  ['W', 'M', 1.0],
#  ['B', 'D', 1.0],
#  ['B', 'B', 1.0],
#  ['M', 'M', 1.0],
#  ['W', 'W', 1],
#  ['C', 'U', 1.0],
#  ['X', 'T', 1.0],
#  ['A', 'J', 1.0],
#  ['J', 'H', 1.0],
#  ['L', 'E', 1],
#  ['C', 'E', 1.0],
#  ['H', 'F', 1.0],
#  ['O', 'N', 1.0],
#  ['Y', 'F', 1.0],
#  ['J', 'J', 1],
#  ['R', 'H', 1.0],
#  ['J', 'I', 1.0],
#  ['S', 'Q', 1.0],
#  ['K', 'R', 1.0],
#  ['W', 'W', 1],
#  ['Q', 'O', 1.0],
#  ['K', 'G', 1.0],
#  ['J', 'A', 1.0],
#  ['U', 'T', 1.0],
#  ['W', 'W', 1],
#  ['U', 'N', 1.0],
#  ['G', 'S', 1.0],
#  ['J', 'I', 1.0],
#  ['G', 'K', 1.0],
#  ['C', 'C', 1],
#  ['N', 'V', 1.0],
#  ['N', 'H', 1.3336148155022614e-34],
#  ['H', 'N', 1.0],
#  ['R', 'A', 1.0],
#  ['R', 'R', 1],
#  ['Z', 'S', 1.0],
#  ['G', 'S', 1.0],
#  ['P', 'F', 1.0],
#  ['G', 'Q', 1.0],
#  ['G', 'G', 1],
#  ['F', 'T', 1.0],
#  ['J', 'A', 1.0],
#  ['Q', 'A', 1.0],
#  ['M', 'N', 1.0],
#  ['A', 'A', 1],
#  ['H', 'F', 1.0],
#  ['K', 'E', 1.0],
#  ['O', 'D', 1.0],
#  ['G', 'Q', 1.0],
#  ['R', 'R', 1],
#  ['E', 'T', 1.0],
#  ['S', 'Z', 1.0],
#  ['O', 'N', 1.0],
#  ['R', 'M', 1.0],
#  ['J', 'J', 1],
#  ['H', 'V', 1.0],
#  ['E', 'K', 1.0],
#  ['A', 'Y', 1.0],
#  ['C', 'E', 1.0],
#  ['L', 'L', 1],
#  ['O', 'T', 1.0],
#  ['Z', 'S', 1.0],
#  ['Z', 'E', 2.678636961808078e-33],
#  ['K', 'X', 1.0],
#  ['T', 'T', 1],
#  ['C', 'U', 1.0],
#  ['W', 'N', 1.0],
#  ['J', 'I', 1.0],
#  ['K', 'X', 1.0],
#  ['J', 'S', 1],
#  ['Y', 'T', 1.0],
#  ['T', 'Y', 1.0],
#  ['Z', 'S', 1.0],
#  ['H', 'N', 1.0],
#  ['D', 'D', 1],
#  ['Z', 'S', 1.0],
#  ['H', 'O', 1.0],
#  ['I', 'F', 1.0],
#  ['E', 'T', 1.0],
#  ['Q', 'Q', 1],
#  ['N', 'K', 1.0],
#  ['E', 'Q', 1.0],
#  ['C', 'H', 1.0],
#  ['U', 'H', 1.0],
#  ['H', 'U', 1],
#  ['V', 'Y', 1.0],
#  ['X', 'E', 1.0],
#  ['S', 'X', 1.0],
#  ['O', 'H', 1.0],
#  ['Y', 'Y', 1],
#  ['S', 'Z', 1.0],
#  ['C', 'E', 1.0],
#  ['Z', 'E', 1.0],
#  ['R', 'N', 1.0],
#  ['J', 'J', 1],
#  ['R', 'O', 1.0],
#  ['H', 'F', 1.0],
#  ['R', 'B', 1.0],
#  ['J', 'E', 1.0],
#  ['M', 'M', 1],
#  ['O', 'R', 1.0],
#  ['F', 'T', 1.0],
#  ['H', 'F', 1.0],
#  ['N', 'V', 1.0],
#  ['V', 'V', 1],
#  ['Y', 'V', 1.0],
#  ['S', 'Y', 1.0],
#  ['O', 'H', 1.0],
#  ['S', 'G', 1.0],
#  ['G', 'Q', 1],
#  ['R', 'B', 1.0],
#  ['X', 'D', 1.0],
#  ['G', 'R', 1.0],
#  ['L', 'E', 1.0],
#  ['D', 'D', 1],
#  ['Y', 'F', 1.0],
#  ['I', 'Z', 1.0],
#  ['V', 'F', 1.0],
#  ['G', 'E', 1.0],
#  ['G', 'G', 1],
#  ['S', 'B', 1.0],
#  ['S', 'Q', 5.501611081740457e-118],
#  ['K', 'R', 1.0],
#  ['L', 'X', 1.0],
#  ['C', 'C', 1],
#  ['B', 'E', 1.0],
#  ['W', 'W', 1.0],
#  ['J', 'F', 1.0],
#  ['R', 'D', 1.0],
#  ['M', 'M', 1],
#  ['H', 'O', 1.0],
#  ['P', 'F', 1.0],
#  ['F', 'G', 1.0],
#  ['Z', 'S', 1.0],
#  ['L', 'L', 1],
#  ['R', 'E', 1.0],
#  ['Q', 'O', 1.0],
#  ['G', 'Q', 1.0],
#  ['H', 'O', 1.0],
#  ['S', 'S', 1],
#  ['T', 'Y', 1.0],
#  ['S', 'G', 1.0],
#  ['G', 'O', 1.0],
#  ['V', 'A', 1.0],
#  ['K', 'X', 1],
#  ['I', 'B', 1.0],
#  ['R', 'V', 1.0],
#  ['H', 'D', 1.0],
#  ['L', 'G', 1.0],
#  ['M', 'M', 1],
#  ['A', 'N', 1.0],
#  ['L', 'K', 1.0],
#  ['Q', 'J', 1.0],
#  ['S', 'T', 1.0],
#  ['T', 'T', 1],
#  ['D', 'I', 1.0],
#  ['G', 'E', 1.0],
#  ['T', 'G', 1.0],
#  ['H', 'C', 1.0],
#  ['L', 'L', 1],
#  ['G', 'E', 1.0],
#  ['Q', 'O', 1.0],
#  ['L', 'Q', 1.0],
#  ['P', 'F', 1.0],
#  ['T', 'T', 1],
#  ['P', 'F', 1.0],
#  ['K', 'U', 1.0],
#  ['P', 'Y', 1.0],
#  ['S', 'E', 1.0],
#  ['T', 'T', 1],
#  ['U', 'L', 1.0],
#  ['X', 'G', 1.0],
#  ['R', 'B', 1.0],
#  ['Z', 'Q', 1.0],
#  ['U', 'U', 1],
#  ['H', 'D', 1.0],
#  ['H', 'R', 2.2856936767186716e-49],
#  ['L', 'Q', 1.0],
#  ['O', 'Q', 1.0],
#  ['R', 'R', 1],
#  ['R', 'X', 3.7485539715481897e-163],
#  ['Q', 'B', 1.0],
#  ['K', 'L', 1.0],
#  ['G', 'C', 1.0],
#  ['V', 'V', 1],
#  ['T', 'Y', 1.0],
#  ['Q', 'B', 1.0],
#  ['O', 'H', 1.0],
#  ['S', 'Y', 1.0],
#  ['K', 'K', 1],
#  ['P', 'E', 1.0],
#  ['H', 'F', 1.0],
#  ['E', 'Q', 1.0],
#  ['I', 'J', 1.0],
#  ['K', 'R', 1],
#  ['O', 'D', 1.0],
#  ['S', 'E', 1.0],
#  ['A', 'M', 1.0],
#  ['L', 'I', 1.0],
#  ['P', 'P', 1],
#  ['K', 'A', 1.0],
#  ['O', 'G', 1.0],
#  ['C', 'K', 1.0],
#  ['X', 'L', 1.0],
#  ['M', 'M', 1],
#  ['S', 'Q', 1.0],
#  ['K', 'E', 1.0],
#  ['S', 'G', 1.0],
#  ['K', 'M', 1.0],
#  ['G', 'G', 1],
#  ['D', 'O', 1.0],
#  ['Z', 'S', 1.0],
#  ['G', 'Q', 1.0],
#  ['S', 'B', 1.0],
#  ['I', 'I', 1],
#  ['C', 'K', 1.0],
#  ['H', 'T', 1.0],
#  ['L', 'E', 1.0],
#  ['Y', 'D', 1.0],
#  ['F', 'F', 1],
#  ['V', 'A', 1.0],
#  ['H', 'B', 1.0],
#  ['B', 'R', 1.0],
#  ['N', 'N', 1.0],
#  ['F', 'F', 1],
#  ['K', 'R', 1.0],
#  ['S', 'B', 1.0],
#  ['Y', 'M', 1.0],
#  ['U', 'V', 1.0],
#  ['P', 'Y', 1],
#  ['M', 'G', 1.0],
#  ['S', 'X', 1.0],
#  ['L', 'Q', 1.0],
#  ['K', 'E', 1.0],
#  ['R', 'V', 1],
#  ['D', 'R', 1.0],
#  ['B', 'Q', 1.0],
#  ['V', 'V', 1.0],
#  ['S', 'I', 1.0],
#  ['Z', 'Z', 1],
#  ['C', 'K', 1.0],
#  ['E', 'X', 1.0],
#  ['J', 'F', 1.0],
#  ['J', 'S', 3.5722699376192174e-67],
#  ['V', 'V', 1],
#  ['Q', 'O', 1.0],
#  ['I', 'J', 1.0],
#  ['H', 'X', 1.0],
#  ['N', 'O', 1.0],
#  ['M', 'M', 1],
#  ['P', 'D', 1.0],
#  ['S', 'B', 1.0],
#  ['Z', 'S', 1.0],
#  ['F', 'E', 1.0],
#  ['W', 'W', 1],
#  ['H', 'T', 1.0],
#  ['H', 'V', 1.580420060273613e-61],
#  ['J', 'I', 1.0],
#  ['J', 'F', 2.319522830243569e-16],
#  ['O', 'O', 1],
#  ['C', 'Q', 1.0],
#  ['K', 'Y', 1.0],
#  ['U', 'D', 1.0],
#  ['E', 'L', 1.0],
#  ['J', 'J', 1],
#  ['H', 'O', 1.0],
#  ['C', 'L', 1.0],
#  ['X', 'E', 1.0],
#  ['G', 'R', 1.0],
#  ['I', 'I', 1],
#  ['R', 'K', 1.0],
#  ['D', 'B', 1.0],
#  ['M', 'W', 1.0],
#  ['D', 'H', 1.0],
#  ['Q', 'Q', 1],
#  ['T', 'E', 1.0],
#  ['G', 'Q', 1.0],
#  ['F', 'E', 1.0],
#  ['Y', 'V', 1.0],
#  ['J', 'J', 1],
#  ['N', 'D', 1.0],
#  ['F', 'P', 1.0],
#  ['K', 'U', 1.0],
#  ['J', 'I', 1.0],
#  ['T', 'T', 1],
#  ['C', 'E', 1.0],
#  ['E', 'L', 1.0],
#  ['D', 'R', 1.0],
#  ['M', 'N', 1.0],
#  ['X', 'X', 1],
#  ['H', 'O', 1.0],
#  ['F', 'T', 1.0],
#  ['Z', 'S', 1.0],
#  ['K', 'R', 1.0],
#  ['Z', 'Z', 1],
#  ['D', 'G', 1.0],
#  ['S', 'A', 1.0],
#  ['Y', 'A', 1.0],
#  ['S', 'Z', 1.0],
#  ['C', 'C', 1],
#  ['B', 'V', 1.0],
#  ['L', 'L', 1.0],
#  ['X', 'D', 1.0],
#  ['J', 'I', 1.0],
#  ['J', 'J', 1],
#  ['V', 'Y', 1.0],
#  ['J', 'S', 1.0],
#  ['J', 'F', 2.319522830243569e-16],
#  ['O', 'H', 1.0],
#  ['V', 'V', 1],
#  ['C', 'R', 1.0],
#  ['S', 'I', 1.0],
#  ['T', 'F', 1.0],
#  ['E', 'C', 1.0],
#  ['P', 'P', 1],
#  ['U', 'H', 1.0],
#  ['Z', 'Q', 1.0],
#  ['Q', 'A', 1.0],
#  ['O', 'W', 1.0],
#  ['E', 'E', 1],
#  ['C', 'G', 1.0],
#  ['T', 'S', 1.0],
#  ['Z', 'S', 1.0],
#  ['N', 'W', 1.0],
#  ['Q', 'Q', 1],
#  ['Y', 'V', 1.0],
#  ['Z', 'A', 1.0],
#  ['F', 'P', 1.0],
#  ['H', 'N', 1.0],
#  ['M', 'M', 1],
#  ['K', 'X', 1.0],
#  ['X', 'E', 1.0],
#  ['H', 'V', 1.0],
#  ['E', 'T', 1.0],
#  ['D', 'D', 1],
#  ['E', 'B', 1.0],
#  ['G', 'Q', 1.0],
#  ['X', 'L', 1.0],
#  ['S', 'Z', 1.0],
#  ['W', 'O', 1],
#  ['C', 'E', 1.0],
#  ['R', 'O', 1.0],
#  ['E', 'G', 1.0],
#  ['P', 'G', 1.0],
#  ['O', 'H', 1],
#  ...]

# %% [markdown]
# Save data from generated markov chain

# %%
markov.to_csv("KmarkovSamplesLetters.csv")

# %%
prob=[]
for i in predProb:
    prob.append(i[2])

# %%
markov['probability']=prob

# %%
markov.to_csv("KmarkovSamplesLettersProbability.csv")

# %%
for i in lst:
    letters=letters.drop([i])
letters.to_csv('KmarkovLettersRemaining.csv')

# %% [markdown]
# # SVM

# %%
train = pd.read_csv("KmarkovSamplesLetters.csv")
test = pd.read_csv("KmarkovLettersRemaining.csv")

# %%
train = train.drop(train.columns[[0]], axis=1)
test = test.drop(test.columns[[0]], axis=1)
train.columns = ['letter', 'xbox', 'ybox', 'width', 'height', 'onpix', 'xbar','ybar', 'x2bar', 'y2bar', 'xybar', 'x2ybar', 'xy2bar', 'xedge','xedgey', 'yedge', 'yedgex']
test.columns = ['letter', 'xbox', 'ybox', 'width', 'height', 'onpix', 'xbar','ybar', 'x2bar', 'y2bar', 'xybar', 'x2ybar', 'xy2bar', 'xedge','xedgey', 'yedge', 'yedgex']

# %%
X_train = train.drop("letter", axis = 1)
y_train = train["letter"]

X_test = test.drop("letter", axis = 1)
y_test = test["letter"]

# %% [markdown]
# Linear kernel

# %%
model_linear = SVC(kernel='linear')
model_linear.fit(X_train, y_train)

# predict

y_pred = model_linear.predict(X_test)
print("accuracy:", metrics.accuracy_score(y_true=y_test, y_pred=y_pred), "\n")
# Out:
# accuracy: 0.8121266619564519

# %% [markdown]
# RBF kernel

# %%
model_linear = SVC(kernel='rbf')
model_linear.fit(X_train, y_train)

# predict
y_pred = model_linear.predict(X_test)
print("accuracy:", metrics.accuracy_score(y_true=y_test, y_pred=y_pred), "\n")
# Out:
# accuracy: 0.8694842314856446

# %% [markdown]
# Chi-squared kernel

# %%
from sklearn.metrics.pairwise import chi2_kernel

model_linear = SVC(kernel=chi2_kernel)
model_linear.fit(X_train, y_train)

y_pred = model_linear.predict(X_test)
print("accuracy:", metrics.accuracy_score(y_true=y_test, y_pred=y_pred), "\n")
# Out:
# accuracy: 0.8495728691630805

# %% [markdown]
# Hellinger kernel

# %%
def hellinger(X1, X2):

  return np.sqrt(np.dot(X1,X2.T))
   

model_linear = SVC(kernel=hellinger)
model_linear.fit(X_train, y_train)

# predict
y_pred = model_linear.predict(X_test)
print("accuracy:", metrics.accuracy_score(y_true=y_test, y_pred=y_pred), "\n")
# Out:
# accuracy: 0.709229879889524

# %% [markdown]
# Intersection kernel

# %%
from sklearn.metrics.pairwise import euclidean_distances

def intersection(X1,X2):

  # X1= n1 x m
  # X2= n2 x m
  # result= n1xn2

  result = np.zeros((X1.shape[0],X2.shape[0]))
  X2=X2.T

  for i in range(len(X1)):
    # iterate through columns of Y
    for j in range(len(X2[0])):
      # iterate through rows of Y
      val=float('+inf')
      for k in range(len(X2)):
        val = min(val,X1[i][k] * X2[k][j])

      result[i][j]=val

  return result
 

model_linear = SVC(kernel=intersection)
model_linear.fit(X_train, y_train)

# predict
y_pred = model_linear.predict(X_test)
print("accuracy:", metrics.accuracy_score(y_true=y_test, y_pred=y_pred), "\n")

# Taking too much time.
# Out:
# accuracy: 0.01920483011111825
